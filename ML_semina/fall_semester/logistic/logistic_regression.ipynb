# %% [markdown]
# ## 로지스틱 회귀분석
#
# 코드를 이해하기 위한 예제

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')

print('Using Pytorch version : ',torch.__version__,' Device : ',DEVICE)
# Out:
# Using Pytorch version :  1.9.0  Device :  cuda

# %%
torch.manual_seed(1)
x_data = [[1, 2], [2, 3], [3, 1], [4, 3], [5, 3], [6, 2]]
y_data = [[0], [0], [0], [1], [1], [1]]
x_train = torch.FloatTensor(x_data)
y_train = torch.FloatTensor(y_data)
#훈련 데이터 선언
print(x_train.shape)
print(y_train.shape)

#XW 결과 Y가 되려면. W:2x1 백터여야한다.
# Out:
# torch.Size([6, 2])
# torch.Size([6, 1])

# %%
W = torch.zeros((2, 1), requires_grad=True) # 크기는 2 x 1
b = torch.zeros(1, requires_grad=True)

# %%
#가설 세우고 확인
#W=0 일때
hypothesis = 1 / (1 + torch.exp(-(x_train.matmul(W) + b)))
print(hypothesis)
# Out:
# tensor([[0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000]], grad_fn=<MulBackward0>)

# %%
hypothesis = torch.sigmoid(x_train.matmul(W) + b)
print(hypothesis)
# Out:
# tensor([[0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000]], grad_fn=<SigmoidBackward0>)

# %%
#.binary_cross_entropy(예측값, 실제값)
#로지스틱 회귀 비용함수를 cross_entropy라고 한다.
#cost function. loss를 구한것.
F.binary_cross_entropy(hypothesis, y_train)
# Out:
# tensor(0.6931, grad_fn=<BinaryCrossEntropyBackward0>)

# %%
#전체 과정

W = torch.zeros((2, 1), requires_grad=True) # 크기는 2 x 1
b = torch.zeros(1, requires_grad=True)

# optimizer 설정
optimizer = optim.SGD([W, b], lr=1)#여기서 W와 b를 계산 해야한다!

nb_epochs = 1000
for epoch in range(nb_epochs + 1):

    # Cost 계산
    hypothesis = torch.sigmoid(x_train.matmul(W) + b)
    cost = -(y_train * torch.log(hypothesis) + 
             (1 - y_train) * torch.log(1 - hypothesis)).mean()

    # cost로 H(x) 계산
    optimizer.zero_grad() #zero_grad는 gradient를 매 epoch마다 0으로 초기화
    cost.backward()
    optimizer.step()

    # 100번마다 로그 출력
    if epoch % 100 == 0:
        print('Epoch {:4d}/{} Cost: {:.6f}'.format(
            epoch, nb_epochs, cost.item()
        ))
# Out:
# Epoch    0/1000 Cost: 0.693147
# Epoch  100/1000 Cost: 0.134722
# Epoch  200/1000 Cost: 0.080643
# Epoch  300/1000 Cost: 0.057900
# Epoch  400/1000 Cost: 0.045300
# Epoch  500/1000 Cost: 0.037261
# Epoch  600/1000 Cost: 0.031673
# Epoch  700/1000 Cost: 0.027556
# Epoch  800/1000 Cost: 0.024394
# Epoch  900/1000 Cost: 0.021888
# Epoch 1000/1000 Cost: 0.019852

# %%
print(W,b)
hypothesis = torch.sigmoid(x_train.matmul(W) + b)
prediction = hypothesis >= torch.FloatTensor([0.5])
print(prediction)
# Out:
# tensor([[3.2530],
#         [1.5179]], requires_grad=True) tensor([-14.4819], requires_grad=True)
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])

# %%
#Weight에 절대값을 주는 방법
#Shifted weighted
#이떄는 학습이 안된다.


W = torch.randn((2, 1), requires_grad=True) # 크기는 2 x 1
b = torch.zeros(1, requires_grad=True)

# optimizer 설정
optimizer = optim.SGD([W, b], lr=1)#여기서 W와 b를 계산 해야한다!

nb_epochs = 1000
for epoch in range(nb_epochs + 1):

    # Cost 계산
    hypothesis = torch.sigmoid(x_train.matmul(torch.abs(W)) + b)
    cost = -(y_train * torch.log(hypothesis) + 
             (1 - y_train) * torch.log(1 - hypothesis)).mean()
    print(cost)
    # cost로 H(x) 계산
    optimizer.zero_grad() #zero_grad는 gradient를 매 epoch마다 0으로 초기화
    cost.backward()
    optimizer.step()

    # 100번마다 로그 출력
    if epoch % 100 == 0:
        print('Epoch {:4d}/{} Cost: {:.6f}'.format(
            epoch, nb_epochs, cost.item()
        ))
# Out:
# tensor(1.0176, grad_fn=<NegBackward>)
# Epoch    0/1000 Cost: 1.017644
# tensor(0.7487, grad_fn=<NegBackward>)
# tensor(0.5380, grad_fn=<NegBackward>)
# tensor(0.6254, grad_fn=<NegBackward>)
# tensor(0.5820, grad_fn=<NegBackward>)
# tensor(0.5445, grad_fn=<NegBackward>)
# tensor(0.6983, grad_fn=<NegBackward>)
# tensor(1.6294, grad_fn=<NegBackward>)
# tensor(0.4140, grad_fn=<NegBackward>)
# tensor(0.4230, grad_fn=<NegBackward>)
# tensor(0.6211, grad_fn=<NegBackward>)
# tensor(0.4268, grad_fn=<NegBackward>)
# tensor(0.5390, grad_fn=<NegBackward>)
# tensor(0.6895, grad_fn=<NegBackward>)
# tensor(1.6801, grad_fn=<NegBackward>)
# tensor(0.3026, grad_fn=<NegBackward>)
# tensor(0.2972, grad_fn=<NegBackward>)
# tensor(0.2939, grad_fn=<NegBackward>)
# tensor(0.2886, grad_fn=<NegBackward>)
# tensor(0.2893, grad_fn=<NegBackward>)
# tensor(0.2874, grad_fn=<NegBackward>)
# tensor(0.3129, grad_fn=<NegBackward>)
# tensor(0.3028, grad_fn=<NegBackward>)
# tensor(0.3945, grad_fn=<NegBackward>)
# tensor(0.3541, grad_fn=<NegBackward>)
# tensor(0.6142, grad_fn=<NegBackward>)
# tensor(0.3486, grad_fn=<NegBackward>)
# tensor(0.6050, grad_fn=<NegBackward>)
# tensor(0.3414, grad_fn=<NegBackward>)
# tensor(0.5806, grad_fn=<NegBackward>)
# tensor(0.3126, grad_fn=<NegBackward>)
# tensor(0.4868, grad_fn=<NegBackward>)
# tensor(0.3082, grad_fn=<NegBackward>)
# tensor(0.4711, grad_fn=<NegBackward>)
# tensor(0.2880, grad_fn=<NegBackward>)
# tensor(0.4103, grad_fn=<NegBackward>)
# tensor(0.2794, grad_fn=<NegBackward>)
# tensor(0.3834, grad_fn=<NegBackward>)
# tensor(0.2633, grad_fn=<NegBackward>)
# tensor(0.3403, grad_fn=<NegBackward>)
# tensor(0.2538, grad_fn=<NegBackward>)
# tensor(0.3150, grad_fn=<NegBackward>)
# tensor(0.2404, grad_fn=<NegBackward>)
# tensor(0.2839, grad_fn=<NegBackward>)
# tensor(0.2271, grad_fn=<NegBackward>)
# tensor(0.2563, grad_fn=<NegBackward>)
# tensor(0.2134, grad_fn=<NegBackward>)
# tensor(0.2312, grad_fn=<NegBackward>)
# tensor(0.2012, grad_fn=<NegBackward>)
# tensor(0.2111, grad_fn=<NegBackward>)
# tensor(0.1907, grad_fn=<NegBackward>)
# tensor(0.1955, grad_fn=<NegBackward>)
# tensor(0.1817, grad_fn=<NegBackward>)
# tensor(0.1833, grad_fn=<NegBackward>)
# tensor(0.1741, grad_fn=<NegBackward>)
# tensor(0.1739, grad_fn=<NegBackward>)
# tensor(0.1677, grad_fn=<NegBackward>)
# tensor(0.1665, grad_fn=<NegBackward>)
# tensor(0.1624, grad_fn=<NegBackward>)
# tensor(0.1609, grad_fn=<NegBackward>)
# tensor(0.1580, grad_fn=<NegBackward>)
# tensor(0.1564, grad_fn=<NegBackward>)
# tensor(0.1543, grad_fn=<NegBackward>)
# tensor(0.1528, grad_fn=<NegBackward>)
# tensor(0.1512, grad_fn=<NegBackward>)
# tensor(0.1499, grad_fn=<NegBackward>)
# tensor(0.1485, grad_fn=<NegBackward>)
# tensor(0.1473, grad_fn=<NegBackward>)
# tensor(0.1461, grad_fn=<NegBackward>)
# tensor(0.1450, grad_fn=<NegBackward>)
# tensor(0.1439, grad_fn=<NegBackward>)
# tensor(0.1428, grad_fn=<NegBackward>)
# tensor(0.1418, grad_fn=<NegBackward>)
# tensor(0.1407, grad_fn=<NegBackward>)
# tensor(0.1397, grad_fn=<NegBackward>)
# tensor(0.1388, grad_fn=<NegBackward>)
# tensor(0.1378, grad_fn=<NegBackward>)
# tensor(0.1368, grad_fn=<NegBackward>)
# tensor(0.1359, grad_fn=<NegBackward>)
# tensor(0.1350, grad_fn=<NegBackward>)
# tensor(0.1341, grad_fn=<NegBackward>)
# tensor(0.1332, grad_fn=<NegBackward>)
# tensor(0.1323, grad_fn=<NegBackward>)
# tensor(0.1314, grad_fn=<NegBackward>)
# tensor(0.1305, grad_fn=<NegBackward>)
# tensor(0.1297, grad_fn=<NegBackward>)
# tensor(0.1288, grad_fn=<NegBackward>)
# tensor(0.1280, grad_fn=<NegBackward>)
# tensor(0.1272, grad_fn=<NegBackward>)
# tensor(0.1264, grad_fn=<NegBackward>)
# tensor(0.1256, grad_fn=<NegBackward>)
# tensor(0.1248, grad_fn=<NegBackward>)
# tensor(0.1240, grad_fn=<NegBackward>)
# tensor(0.1233, grad_fn=<NegBackward>)
# tensor(0.1225, grad_fn=<NegBackward>)
# tensor(0.1217, grad_fn=<NegBackward>)
# tensor(0.1210, grad_fn=<NegBackward>)
# tensor(0.1203, grad_fn=<NegBackward>)
# tensor(0.1196, grad_fn=<NegBackward>)
# tensor(0.1188, grad_fn=<NegBackward>)
# tensor(0.1181, grad_fn=<NegBackward>)
# Epoch  100/1000 Cost: 0.118138
# tensor(0.1174, grad_fn=<NegBackward>)
# tensor(0.1168, grad_fn=<NegBackward>)
# tensor(0.1161, grad_fn=<NegBackward>)
# tensor(0.1154, grad_fn=<NegBackward>)
# tensor(0.1147, grad_fn=<NegBackward>)
# tensor(0.1141, grad_fn=<NegBackward>)
# tensor(0.1134, grad_fn=<NegBackward>)
# tensor(0.1128, grad_fn=<NegBackward>)
# tensor(0.1122, grad_fn=<NegBackward>)
# tensor(0.1115, grad_fn=<NegBackward>)
# tensor(0.1109, grad_fn=<NegBackward>)
# tensor(0.1103, grad_fn=<NegBackward>)
# tensor(0.1097, grad_fn=<NegBackward>)
# tensor(0.1091, grad_fn=<NegBackward>)
# tensor(0.1085, grad_fn=<NegBackward>)
# tensor(0.1079, grad_fn=<NegBackward>)
# tensor(0.1074, grad_fn=<NegBackward>)
# tensor(0.1068, grad_fn=<NegBackward>)
# tensor(0.1062, grad_fn=<NegBackward>)
# tensor(0.1057, grad_fn=<NegBackward>)
# tensor(0.1051, grad_fn=<NegBackward>)
# tensor(0.1046, grad_fn=<NegBackward>)
# tensor(0.1040, grad_fn=<NegBackward>)
# tensor(0.1035, grad_fn=<NegBackward>)
# tensor(0.1029, grad_fn=<NegBackward>)
# tensor(0.1024, grad_fn=<NegBackward>)
# tensor(0.1019, grad_fn=<NegBackward>)
# tensor(0.1014, grad_fn=<NegBackward>)
# tensor(0.1009, grad_fn=<NegBackward>)
# tensor(0.1004, grad_fn=<NegBackward>)
# tensor(0.0999, grad_fn=<NegBackward>)
# tensor(0.0994, grad_fn=<NegBackward>)
# tensor(0.0989, grad_fn=<NegBackward>)
# tensor(0.0984, grad_fn=<NegBackward>)
# tensor(0.0979, grad_fn=<NegBackward>)
# tensor(0.0975, grad_fn=<NegBackward>)
# tensor(0.0970, grad_fn=<NegBackward>)
# tensor(0.0965, grad_fn=<NegBackward>)
# tensor(0.0961, grad_fn=<NegBackward>)
# tensor(0.0956, grad_fn=<NegBackward>)
# tensor(0.0951, grad_fn=<NegBackward>)
# tensor(0.0947, grad_fn=<NegBackward>)
# tensor(0.0943, grad_fn=<NegBackward>)
# tensor(0.0938, grad_fn=<NegBackward>)
# tensor(0.0934, grad_fn=<NegBackward>)
# tensor(0.0930, grad_fn=<NegBackward>)
# tensor(0.0925, grad_fn=<NegBackward>)
# tensor(0.0921, grad_fn=<NegBackward>)
# tensor(0.0917, grad_fn=<NegBackward>)
# tensor(0.0913, grad_fn=<NegBackward>)
# tensor(0.0909, grad_fn=<NegBackward>)
# tensor(0.0905, grad_fn=<NegBackward>)
# tensor(0.0901, grad_fn=<NegBackward>)
# tensor(0.0897, grad_fn=<NegBackward>)
# tensor(0.0893, grad_fn=<NegBackward>)
# tensor(0.0889, grad_fn=<NegBackward>)
# tensor(0.0885, grad_fn=<NegBackward>)
# tensor(0.0881, grad_fn=<NegBackward>)
# tensor(0.0877, grad_fn=<NegBackward>)
# tensor(0.0873, grad_fn=<NegBackward>)
# tensor(0.0870, grad_fn=<NegBackward>)
# tensor(0.0866, grad_fn=<NegBackward>)
# tensor(0.0862, grad_fn=<NegBackward>)
# tensor(0.0859, grad_fn=<NegBackward>)
# tensor(0.0855, grad_fn=<NegBackward>)
# tensor(0.0851, grad_fn=<NegBackward>)
# tensor(0.0848, grad_fn=<NegBackward>)
# tensor(0.0844, grad_fn=<NegBackward>)
# tensor(0.0841, grad_fn=<NegBackward>)
# tensor(0.0837, grad_fn=<NegBackward>)
# tensor(0.0834, grad_fn=<NegBackward>)
# tensor(0.0830, grad_fn=<NegBackward>)
# tensor(0.0827, grad_fn=<NegBackward>)
# tensor(0.0824, grad_fn=<NegBackward>)
# tensor(0.0820, grad_fn=<NegBackward>)
# tensor(0.0817, grad_fn=<NegBackward>)
# tensor(0.0814, grad_fn=<NegBackward>)
# tensor(0.0811, grad_fn=<NegBackward>)
# tensor(0.0807, grad_fn=<NegBackward>)
# tensor(0.0804, grad_fn=<NegBackward>)
# tensor(0.0801, grad_fn=<NegBackward>)
# tensor(0.0798, grad_fn=<NegBackward>)
# tensor(0.0795, grad_fn=<NegBackward>)
# tensor(0.0792, grad_fn=<NegBackward>)
# tensor(0.0789, grad_fn=<NegBackward>)
# tensor(0.0786, grad_fn=<NegBackward>)
# tensor(0.0782, grad_fn=<NegBackward>)
# tensor(0.0780, grad_fn=<NegBackward>)
# tensor(0.0777, grad_fn=<NegBackward>)
# tensor(0.0774, grad_fn=<NegBackward>)
# tensor(0.0771, grad_fn=<NegBackward>)
# tensor(0.0768, grad_fn=<NegBackward>)
# tensor(0.0765, grad_fn=<NegBackward>)
# tensor(0.0762, grad_fn=<NegBackward>)
# tensor(0.0759, grad_fn=<NegBackward>)
# tensor(0.0756, grad_fn=<NegBackward>)
# tensor(0.0754, grad_fn=<NegBackward>)
# tensor(0.0751, grad_fn=<NegBackward>)
# tensor(0.0748, grad_fn=<NegBackward>)
# tensor(0.0745, grad_fn=<NegBackward>)
# Epoch  200/1000 Cost: 0.074533
# tensor(0.0743, grad_fn=<NegBackward>)
# tensor(0.0740, grad_fn=<NegBackward>)
# tensor(0.0737, grad_fn=<NegBackward>)
# tensor(0.0735, grad_fn=<NegBackward>)
# tensor(0.0732, grad_fn=<NegBackward>)
# tensor(0.0729, grad_fn=<NegBackward>)
# tensor(0.0727, grad_fn=<NegBackward>)
# tensor(0.0724, grad_fn=<NegBackward>)
# tensor(0.0722, grad_fn=<NegBackward>)
# tensor(0.0719, grad_fn=<NegBackward>)
# tensor(0.0717, grad_fn=<NegBackward>)
# tensor(0.0714, grad_fn=<NegBackward>)
# tensor(0.0712, grad_fn=<NegBackward>)
# tensor(0.0709, grad_fn=<NegBackward>)
# tensor(0.0707, grad_fn=<NegBackward>)
# tensor(0.0704, grad_fn=<NegBackward>)
# tensor(0.0702, grad_fn=<NegBackward>)
# tensor(0.0699, grad_fn=<NegBackward>)
# tensor(0.0697, grad_fn=<NegBackward>)
# tensor(0.0695, grad_fn=<NegBackward>)
# tensor(0.0692, grad_fn=<NegBackward>)
# tensor(0.0690, grad_fn=<NegBackward>)
# tensor(0.0688, grad_fn=<NegBackward>)
# tensor(0.0685, grad_fn=<NegBackward>)
# tensor(0.0683, grad_fn=<NegBackward>)
# tensor(0.0681, grad_fn=<NegBackward>)
# tensor(0.0679, grad_fn=<NegBackward>)
# tensor(0.0676, grad_fn=<NegBackward>)
# tensor(0.0674, grad_fn=<NegBackward>)
# tensor(0.0672, grad_fn=<NegBackward>)
# tensor(0.0670, grad_fn=<NegBackward>)
# tensor(0.0668, grad_fn=<NegBackward>)
# tensor(0.0665, grad_fn=<NegBackward>)
# tensor(0.0663, grad_fn=<NegBackward>)
# tensor(0.0661, grad_fn=<NegBackward>)
# tensor(0.0659, grad_fn=<NegBackward>)
# tensor(0.0657, grad_fn=<NegBackward>)
# tensor(0.0655, grad_fn=<NegBackward>)
# tensor(0.0653, grad_fn=<NegBackward>)
# tensor(0.0651, grad_fn=<NegBackward>)
# tensor(0.0649, grad_fn=<NegBackward>)
# tensor(0.0647, grad_fn=<NegBackward>)
# tensor(0.0645, grad_fn=<NegBackward>)
# tensor(0.0643, grad_fn=<NegBackward>)
# tensor(0.0641, grad_fn=<NegBackward>)
# tensor(0.0639, grad_fn=<NegBackward>)
# tensor(0.0637, grad_fn=<NegBackward>)
# tensor(0.0635, grad_fn=<NegBackward>)
# tensor(0.0633, grad_fn=<NegBackward>)
# tensor(0.0631, grad_fn=<NegBackward>)
# tensor(0.0629, grad_fn=<NegBackward>)
# tensor(0.0627, grad_fn=<NegBackward>)
# tensor(0.0625, grad_fn=<NegBackward>)
# tensor(0.0623, grad_fn=<NegBackward>)
# tensor(0.0621, grad_fn=<NegBackward>)
# tensor(0.0619, grad_fn=<NegBackward>)
# tensor(0.0618, grad_fn=<NegBackward>)
# tensor(0.0616, grad_fn=<NegBackward>)
# tensor(0.0614, grad_fn=<NegBackward>)
# tensor(0.0612, grad_fn=<NegBackward>)
# tensor(0.0610, grad_fn=<NegBackward>)
# tensor(0.0608, grad_fn=<NegBackward>)
# tensor(0.0607, grad_fn=<NegBackward>)
# tensor(0.0605, grad_fn=<NegBackward>)
# tensor(0.0603, grad_fn=<NegBackward>)
# tensor(0.0601, grad_fn=<NegBackward>)
# tensor(0.0600, grad_fn=<NegBackward>)
# tensor(0.0598, grad_fn=<NegBackward>)
# tensor(0.0596, grad_fn=<NegBackward>)
# tensor(0.0594, grad_fn=<NegBackward>)
# tensor(0.0593, grad_fn=<NegBackward>)
# tensor(0.0591, grad_fn=<NegBackward>)
# tensor(0.0589, grad_fn=<NegBackward>)
# tensor(0.0588, grad_fn=<NegBackward>)
# tensor(0.0586, grad_fn=<NegBackward>)
# tensor(0.0584, grad_fn=<NegBackward>)
# tensor(0.0583, grad_fn=<NegBackward>)
# tensor(0.0581, grad_fn=<NegBackward>)
# tensor(0.0579, grad_fn=<NegBackward>)
# tensor(0.0578, grad_fn=<NegBackward>)
# tensor(0.0576, grad_fn=<NegBackward>)
# tensor(0.0575, grad_fn=<NegBackward>)
# tensor(0.0573, grad_fn=<NegBackward>)
# tensor(0.0571, grad_fn=<NegBackward>)
# tensor(0.0570, grad_fn=<NegBackward>)
# tensor(0.0568, grad_fn=<NegBackward>)
# tensor(0.0567, grad_fn=<NegBackward>)
# tensor(0.0565, grad_fn=<NegBackward>)
# tensor(0.0564, grad_fn=<NegBackward>)
# tensor(0.0562, grad_fn=<NegBackward>)
# tensor(0.0561, grad_fn=<NegBackward>)
# tensor(0.0559, grad_fn=<NegBackward>)
# tensor(0.0558, grad_fn=<NegBackward>)
# tensor(0.0556, grad_fn=<NegBackward>)
# tensor(0.0555, grad_fn=<NegBackward>)
# tensor(0.0553, grad_fn=<NegBackward>)
# tensor(0.0552, grad_fn=<NegBackward>)
# tensor(0.0550, grad_fn=<NegBackward>)
# tensor(0.0549, grad_fn=<NegBackward>)
# tensor(0.0547, grad_fn=<NegBackward>)
# Epoch  300/1000 Cost: 0.054732
# tensor(0.0546, grad_fn=<NegBackward>)
# tensor(0.0544, grad_fn=<NegBackward>)
# tensor(0.0543, grad_fn=<NegBackward>)
# tensor(0.0542, grad_fn=<NegBackward>)
# tensor(0.0540, grad_fn=<NegBackward>)
# tensor(0.0539, grad_fn=<NegBackward>)
# tensor(0.0537, grad_fn=<NegBackward>)
# tensor(0.0536, grad_fn=<NegBackward>)
# tensor(0.0535, grad_fn=<NegBackward>)
# tensor(0.0533, grad_fn=<NegBackward>)
# tensor(0.0532, grad_fn=<NegBackward>)
# tensor(0.0531, grad_fn=<NegBackward>)
# tensor(0.0529, grad_fn=<NegBackward>)
# tensor(0.0528, grad_fn=<NegBackward>)
# tensor(0.0527, grad_fn=<NegBackward>)
# tensor(0.0525, grad_fn=<NegBackward>)
# tensor(0.0524, grad_fn=<NegBackward>)
# tensor(0.0523, grad_fn=<NegBackward>)
# tensor(0.0521, grad_fn=<NegBackward>)
# tensor(0.0520, grad_fn=<NegBackward>)
# tensor(0.0519, grad_fn=<NegBackward>)
# tensor(0.0517, grad_fn=<NegBackward>)
# tensor(0.0516, grad_fn=<NegBackward>)
# tensor(0.0515, grad_fn=<NegBackward>)
# tensor(0.0514, grad_fn=<NegBackward>)
# tensor(0.0512, grad_fn=<NegBackward>)
# tensor(0.0511, grad_fn=<NegBackward>)
# tensor(0.0510, grad_fn=<NegBackward>)
# tensor(0.0508, grad_fn=<NegBackward>)
# tensor(0.0507, grad_fn=<NegBackward>)
# tensor(0.0506, grad_fn=<NegBackward>)
# tensor(0.0505, grad_fn=<NegBackward>)
# tensor(0.0504, grad_fn=<NegBackward>)
# tensor(0.0502, grad_fn=<NegBackward>)
# tensor(0.0501, grad_fn=<NegBackward>)
# tensor(0.0500, grad_fn=<NegBackward>)
# tensor(0.0499, grad_fn=<NegBackward>)
# tensor(0.0498, grad_fn=<NegBackward>)
# tensor(0.0496, grad_fn=<NegBackward>)
# tensor(0.0495, grad_fn=<NegBackward>)
# tensor(0.0494, grad_fn=<NegBackward>)
# tensor(0.0493, grad_fn=<NegBackward>)
# tensor(0.0492, grad_fn=<NegBackward>)
# tensor(0.0491, grad_fn=<NegBackward>)
# tensor(0.0489, grad_fn=<NegBackward>)
# tensor(0.0488, grad_fn=<NegBackward>)
# tensor(0.0487, grad_fn=<NegBackward>)
# tensor(0.0486, grad_fn=<NegBackward>)
# tensor(0.0485, grad_fn=<NegBackward>)
# tensor(0.0484, grad_fn=<NegBackward>)
# tensor(0.0483, grad_fn=<NegBackward>)
# tensor(0.0481, grad_fn=<NegBackward>)
# tensor(0.0480, grad_fn=<NegBackward>)
# tensor(0.0479, grad_fn=<NegBackward>)
# tensor(0.0478, grad_fn=<NegBackward>)
# tensor(0.0477, grad_fn=<NegBackward>)
# tensor(0.0476, grad_fn=<NegBackward>)
# tensor(0.0475, grad_fn=<NegBackward>)
# tensor(0.0474, grad_fn=<NegBackward>)
# tensor(0.0473, grad_fn=<NegBackward>)
# tensor(0.0472, grad_fn=<NegBackward>)
# tensor(0.0471, grad_fn=<NegBackward>)
# tensor(0.0470, grad_fn=<NegBackward>)
# tensor(0.0469, grad_fn=<NegBackward>)
# tensor(0.0467, grad_fn=<NegBackward>)
# tensor(0.0466, grad_fn=<NegBackward>)
# tensor(0.0465, grad_fn=<NegBackward>)
# tensor(0.0464, grad_fn=<NegBackward>)
# tensor(0.0463, grad_fn=<NegBackward>)
# tensor(0.0462, grad_fn=<NegBackward>)
# tensor(0.0461, grad_fn=<NegBackward>)
# tensor(0.0460, grad_fn=<NegBackward>)
# tensor(0.0459, grad_fn=<NegBackward>)
# tensor(0.0458, grad_fn=<NegBackward>)
# tensor(0.0457, grad_fn=<NegBackward>)
# tensor(0.0456, grad_fn=<NegBackward>)
# tensor(0.0455, grad_fn=<NegBackward>)
# tensor(0.0454, grad_fn=<NegBackward>)
# tensor(0.0453, grad_fn=<NegBackward>)
# tensor(0.0452, grad_fn=<NegBackward>)
# tensor(0.0451, grad_fn=<NegBackward>)
# tensor(0.0450, grad_fn=<NegBackward>)
# tensor(0.0449, grad_fn=<NegBackward>)
# tensor(0.0448, grad_fn=<NegBackward>)
# tensor(0.0447, grad_fn=<NegBackward>)
# tensor(0.0447, grad_fn=<NegBackward>)
# tensor(0.0446, grad_fn=<NegBackward>)
# tensor(0.0445, grad_fn=<NegBackward>)
# tensor(0.0444, grad_fn=<NegBackward>)
# tensor(0.0443, grad_fn=<NegBackward>)
# tensor(0.0442, grad_fn=<NegBackward>)
# tensor(0.0441, grad_fn=<NegBackward>)
# tensor(0.0440, grad_fn=<NegBackward>)
# tensor(0.0439, grad_fn=<NegBackward>)
# tensor(0.0438, grad_fn=<NegBackward>)
# tensor(0.0437, grad_fn=<NegBackward>)
# tensor(0.0436, grad_fn=<NegBackward>)
# tensor(0.0435, grad_fn=<NegBackward>)
# tensor(0.0434, grad_fn=<NegBackward>)
# tensor(0.0434, grad_fn=<NegBackward>)
# Epoch  400/1000 Cost: 0.043356
# tensor(0.0433, grad_fn=<NegBackward>)
# tensor(0.0432, grad_fn=<NegBackward>)
# tensor(0.0431, grad_fn=<NegBackward>)
# tensor(0.0430, grad_fn=<NegBackward>)
# tensor(0.0429, grad_fn=<NegBackward>)
# tensor(0.0428, grad_fn=<NegBackward>)
# tensor(0.0427, grad_fn=<NegBackward>)
# tensor(0.0427, grad_fn=<NegBackward>)
# tensor(0.0426, grad_fn=<NegBackward>)
# tensor(0.0425, grad_fn=<NegBackward>)
# tensor(0.0424, grad_fn=<NegBackward>)
# tensor(0.0423, grad_fn=<NegBackward>)
# tensor(0.0422, grad_fn=<NegBackward>)
# tensor(0.0421, grad_fn=<NegBackward>)
# tensor(0.0421, grad_fn=<NegBackward>)
# tensor(0.0420, grad_fn=<NegBackward>)
# tensor(0.0419, grad_fn=<NegBackward>)
# tensor(0.0418, grad_fn=<NegBackward>)
# tensor(0.0417, grad_fn=<NegBackward>)
# tensor(0.0416, grad_fn=<NegBackward>)
# tensor(0.0416, grad_fn=<NegBackward>)
# tensor(0.0415, grad_fn=<NegBackward>)
# tensor(0.0414, grad_fn=<NegBackward>)
# tensor(0.0413, grad_fn=<NegBackward>)
# tensor(0.0412, grad_fn=<NegBackward>)
# tensor(0.0411, grad_fn=<NegBackward>)
# tensor(0.0411, grad_fn=<NegBackward>)
# tensor(0.0410, grad_fn=<NegBackward>)
# tensor(0.0409, grad_fn=<NegBackward>)
# tensor(0.0408, grad_fn=<NegBackward>)
# tensor(0.0407, grad_fn=<NegBackward>)
# tensor(0.0407, grad_fn=<NegBackward>)
# tensor(0.0406, grad_fn=<NegBackward>)
# tensor(0.0405, grad_fn=<NegBackward>)
# tensor(0.0404, grad_fn=<NegBackward>)
# tensor(0.0404, grad_fn=<NegBackward>)
# tensor(0.0403, grad_fn=<NegBackward>)
# tensor(0.0402, grad_fn=<NegBackward>)
# tensor(0.0401, grad_fn=<NegBackward>)
# tensor(0.0400, grad_fn=<NegBackward>)
# tensor(0.0400, grad_fn=<NegBackward>)
# tensor(0.0399, grad_fn=<NegBackward>)
# tensor(0.0398, grad_fn=<NegBackward>)
# tensor(0.0397, grad_fn=<NegBackward>)
# tensor(0.0397, grad_fn=<NegBackward>)
# tensor(0.0396, grad_fn=<NegBackward>)
# tensor(0.0395, grad_fn=<NegBackward>)
# tensor(0.0394, grad_fn=<NegBackward>)
# tensor(0.0394, grad_fn=<NegBackward>)
# tensor(0.0393, grad_fn=<NegBackward>)
# tensor(0.0392, grad_fn=<NegBackward>)
# tensor(0.0392, grad_fn=<NegBackward>)
# tensor(0.0391, grad_fn=<NegBackward>)
# tensor(0.0390, grad_fn=<NegBackward>)
# tensor(0.0389, grad_fn=<NegBackward>)
# tensor(0.0389, grad_fn=<NegBackward>)
# tensor(0.0388, grad_fn=<NegBackward>)
# tensor(0.0387, grad_fn=<NegBackward>)
# tensor(0.0386, grad_fn=<NegBackward>)
# tensor(0.0386, grad_fn=<NegBackward>)
# tensor(0.0385, grad_fn=<NegBackward>)
# tensor(0.0384, grad_fn=<NegBackward>)
# tensor(0.0384, grad_fn=<NegBackward>)
# tensor(0.0383, grad_fn=<NegBackward>)
# tensor(0.0382, grad_fn=<NegBackward>)
# tensor(0.0382, grad_fn=<NegBackward>)
# tensor(0.0381, grad_fn=<NegBackward>)
# tensor(0.0380, grad_fn=<NegBackward>)
# tensor(0.0380, grad_fn=<NegBackward>)
# tensor(0.0379, grad_fn=<NegBackward>)
# tensor(0.0378, grad_fn=<NegBackward>)
# tensor(0.0377, grad_fn=<NegBackward>)
# tensor(0.0377, grad_fn=<NegBackward>)
# tensor(0.0376, grad_fn=<NegBackward>)
# tensor(0.0375, grad_fn=<NegBackward>)
# tensor(0.0375, grad_fn=<NegBackward>)
# tensor(0.0374, grad_fn=<NegBackward>)
# tensor(0.0373, grad_fn=<NegBackward>)
# tensor(0.0373, grad_fn=<NegBackward>)
# tensor(0.0372, grad_fn=<NegBackward>)
# tensor(0.0371, grad_fn=<NegBackward>)
# tensor(0.0371, grad_fn=<NegBackward>)
# tensor(0.0370, grad_fn=<NegBackward>)
# tensor(0.0370, grad_fn=<NegBackward>)
# tensor(0.0369, grad_fn=<NegBackward>)
# tensor(0.0368, grad_fn=<NegBackward>)
# tensor(0.0368, grad_fn=<NegBackward>)
# tensor(0.0367, grad_fn=<NegBackward>)
# tensor(0.0366, grad_fn=<NegBackward>)
# tensor(0.0366, grad_fn=<NegBackward>)
# tensor(0.0365, grad_fn=<NegBackward>)
# tensor(0.0364, grad_fn=<NegBackward>)
# tensor(0.0364, grad_fn=<NegBackward>)
# tensor(0.0363, grad_fn=<NegBackward>)
# tensor(0.0363, grad_fn=<NegBackward>)
# tensor(0.0362, grad_fn=<NegBackward>)
# tensor(0.0361, grad_fn=<NegBackward>)
# tensor(0.0361, grad_fn=<NegBackward>)
# tensor(0.0360, grad_fn=<NegBackward>)
# tensor(0.0359, grad_fn=<NegBackward>)
# Epoch  500/1000 Cost: 0.035944
# tensor(0.0359, grad_fn=<NegBackward>)
# tensor(0.0358, grad_fn=<NegBackward>)
# tensor(0.0358, grad_fn=<NegBackward>)
# tensor(0.0357, grad_fn=<NegBackward>)
# tensor(0.0356, grad_fn=<NegBackward>)
# tensor(0.0356, grad_fn=<NegBackward>)
# tensor(0.0355, grad_fn=<NegBackward>)
# tensor(0.0355, grad_fn=<NegBackward>)
# tensor(0.0354, grad_fn=<NegBackward>)
# tensor(0.0353, grad_fn=<NegBackward>)
# tensor(0.0353, grad_fn=<NegBackward>)
# tensor(0.0352, grad_fn=<NegBackward>)
# tensor(0.0352, grad_fn=<NegBackward>)
# tensor(0.0351, grad_fn=<NegBackward>)
# tensor(0.0350, grad_fn=<NegBackward>)
# tensor(0.0350, grad_fn=<NegBackward>)
# tensor(0.0349, grad_fn=<NegBackward>)
# tensor(0.0349, grad_fn=<NegBackward>)
# tensor(0.0348, grad_fn=<NegBackward>)
# tensor(0.0348, grad_fn=<NegBackward>)
# tensor(0.0347, grad_fn=<NegBackward>)
# tensor(0.0346, grad_fn=<NegBackward>)
# tensor(0.0346, grad_fn=<NegBackward>)
# tensor(0.0345, grad_fn=<NegBackward>)
# tensor(0.0345, grad_fn=<NegBackward>)
# tensor(0.0344, grad_fn=<NegBackward>)
# tensor(0.0344, grad_fn=<NegBackward>)
# tensor(0.0343, grad_fn=<NegBackward>)
# tensor(0.0343, grad_fn=<NegBackward>)
# tensor(0.0342, grad_fn=<NegBackward>)
# tensor(0.0341, grad_fn=<NegBackward>)
# tensor(0.0341, grad_fn=<NegBackward>)
# tensor(0.0340, grad_fn=<NegBackward>)
# tensor(0.0340, grad_fn=<NegBackward>)
# tensor(0.0339, grad_fn=<NegBackward>)
# tensor(0.0339, grad_fn=<NegBackward>)
# tensor(0.0338, grad_fn=<NegBackward>)
# tensor(0.0338, grad_fn=<NegBackward>)
# tensor(0.0337, grad_fn=<NegBackward>)
# tensor(0.0337, grad_fn=<NegBackward>)
# tensor(0.0336, grad_fn=<NegBackward>)
# tensor(0.0335, grad_fn=<NegBackward>)
# tensor(0.0335, grad_fn=<NegBackward>)
# tensor(0.0334, grad_fn=<NegBackward>)
# tensor(0.0334, grad_fn=<NegBackward>)
# tensor(0.0333, grad_fn=<NegBackward>)
# tensor(0.0333, grad_fn=<NegBackward>)
# tensor(0.0332, grad_fn=<NegBackward>)
# tensor(0.0332, grad_fn=<NegBackward>)
# tensor(0.0331, grad_fn=<NegBackward>)
# tensor(0.0331, grad_fn=<NegBackward>)
# tensor(0.0330, grad_fn=<NegBackward>)
# tensor(0.0330, grad_fn=<NegBackward>)
# tensor(0.0329, grad_fn=<NegBackward>)
# tensor(0.0329, grad_fn=<NegBackward>)
# tensor(0.0328, grad_fn=<NegBackward>)
# tensor(0.0328, grad_fn=<NegBackward>)
# tensor(0.0327, grad_fn=<NegBackward>)
# tensor(0.0327, grad_fn=<NegBackward>)
# tensor(0.0326, grad_fn=<NegBackward>)
# tensor(0.0326, grad_fn=<NegBackward>)
# tensor(0.0325, grad_fn=<NegBackward>)
# tensor(0.0325, grad_fn=<NegBackward>)
# tensor(0.0324, grad_fn=<NegBackward>)
# tensor(0.0324, grad_fn=<NegBackward>)
# tensor(0.0323, grad_fn=<NegBackward>)
# tensor(0.0323, grad_fn=<NegBackward>)
# tensor(0.0322, grad_fn=<NegBackward>)
# tensor(0.0322, grad_fn=<NegBackward>)
# tensor(0.0321, grad_fn=<NegBackward>)
# tensor(0.0321, grad_fn=<NegBackward>)
# tensor(0.0320, grad_fn=<NegBackward>)
# tensor(0.0320, grad_fn=<NegBackward>)
# tensor(0.0319, grad_fn=<NegBackward>)
# tensor(0.0319, grad_fn=<NegBackward>)
# tensor(0.0318, grad_fn=<NegBackward>)
# tensor(0.0318, grad_fn=<NegBackward>)
# tensor(0.0317, grad_fn=<NegBackward>)
# tensor(0.0317, grad_fn=<NegBackward>)
# tensor(0.0316, grad_fn=<NegBackward>)
# tensor(0.0316, grad_fn=<NegBackward>)
# tensor(0.0315, grad_fn=<NegBackward>)
# tensor(0.0315, grad_fn=<NegBackward>)
# tensor(0.0315, grad_fn=<NegBackward>)
# tensor(0.0314, grad_fn=<NegBackward>)
# tensor(0.0314, grad_fn=<NegBackward>)
# tensor(0.0313, grad_fn=<NegBackward>)
# tensor(0.0313, grad_fn=<NegBackward>)
# tensor(0.0312, grad_fn=<NegBackward>)
# tensor(0.0312, grad_fn=<NegBackward>)
# tensor(0.0311, grad_fn=<NegBackward>)
# tensor(0.0311, grad_fn=<NegBackward>)
# tensor(0.0310, grad_fn=<NegBackward>)
# tensor(0.0310, grad_fn=<NegBackward>)
# tensor(0.0309, grad_fn=<NegBackward>)
# tensor(0.0309, grad_fn=<NegBackward>)
# tensor(0.0309, grad_fn=<NegBackward>)
# tensor(0.0308, grad_fn=<NegBackward>)
# tensor(0.0308, grad_fn=<NegBackward>)
# tensor(0.0307, grad_fn=<NegBackward>)
# Epoch  600/1000 Cost: 0.030720
# tensor(0.0307, grad_fn=<NegBackward>)
# tensor(0.0306, grad_fn=<NegBackward>)
# tensor(0.0306, grad_fn=<NegBackward>)
# tensor(0.0305, grad_fn=<NegBackward>)
# tensor(0.0305, grad_fn=<NegBackward>)
# tensor(0.0305, grad_fn=<NegBackward>)
# tensor(0.0304, grad_fn=<NegBackward>)
# tensor(0.0304, grad_fn=<NegBackward>)
# tensor(0.0303, grad_fn=<NegBackward>)
# tensor(0.0303, grad_fn=<NegBackward>)
# tensor(0.0302, grad_fn=<NegBackward>)
# tensor(0.0302, grad_fn=<NegBackward>)
# tensor(0.0302, grad_fn=<NegBackward>)
# tensor(0.0301, grad_fn=<NegBackward>)
# tensor(0.0301, grad_fn=<NegBackward>)
# tensor(0.0300, grad_fn=<NegBackward>)
# tensor(0.0300, grad_fn=<NegBackward>)
# tensor(0.0299, grad_fn=<NegBackward>)
# tensor(0.0299, grad_fn=<NegBackward>)
# tensor(0.0299, grad_fn=<NegBackward>)
# tensor(0.0298, grad_fn=<NegBackward>)
# tensor(0.0298, grad_fn=<NegBackward>)
# tensor(0.0297, grad_fn=<NegBackward>)
# tensor(0.0297, grad_fn=<NegBackward>)
# tensor(0.0296, grad_fn=<NegBackward>)
# tensor(0.0296, grad_fn=<NegBackward>)
# tensor(0.0296, grad_fn=<NegBackward>)
# tensor(0.0295, grad_fn=<NegBackward>)
# tensor(0.0295, grad_fn=<NegBackward>)
# tensor(0.0294, grad_fn=<NegBackward>)
# tensor(0.0294, grad_fn=<NegBackward>)
# tensor(0.0294, grad_fn=<NegBackward>)
# tensor(0.0293, grad_fn=<NegBackward>)
# tensor(0.0293, grad_fn=<NegBackward>)
# tensor(0.0292, grad_fn=<NegBackward>)
# tensor(0.0292, grad_fn=<NegBackward>)
# tensor(0.0292, grad_fn=<NegBackward>)
# tensor(0.0291, grad_fn=<NegBackward>)
# tensor(0.0291, grad_fn=<NegBackward>)
# tensor(0.0290, grad_fn=<NegBackward>)
# tensor(0.0290, grad_fn=<NegBackward>)
# tensor(0.0290, grad_fn=<NegBackward>)
# tensor(0.0289, grad_fn=<NegBackward>)
# tensor(0.0289, grad_fn=<NegBackward>)
# tensor(0.0288, grad_fn=<NegBackward>)
# tensor(0.0288, grad_fn=<NegBackward>)
# tensor(0.0288, grad_fn=<NegBackward>)
# tensor(0.0287, grad_fn=<NegBackward>)
# tensor(0.0287, grad_fn=<NegBackward>)
# tensor(0.0286, grad_fn=<NegBackward>)
# tensor(0.0286, grad_fn=<NegBackward>)
# tensor(0.0286, grad_fn=<NegBackward>)
# tensor(0.0285, grad_fn=<NegBackward>)
# tensor(0.0285, grad_fn=<NegBackward>)
# tensor(0.0285, grad_fn=<NegBackward>)
# tensor(0.0284, grad_fn=<NegBackward>)
# tensor(0.0284, grad_fn=<NegBackward>)
# tensor(0.0283, grad_fn=<NegBackward>)
# tensor(0.0283, grad_fn=<NegBackward>)
# tensor(0.0283, grad_fn=<NegBackward>)
# tensor(0.0282, grad_fn=<NegBackward>)
# tensor(0.0282, grad_fn=<NegBackward>)
# tensor(0.0282, grad_fn=<NegBackward>)
# tensor(0.0281, grad_fn=<NegBackward>)
# tensor(0.0281, grad_fn=<NegBackward>)
# tensor(0.0280, grad_fn=<NegBackward>)
# tensor(0.0280, grad_fn=<NegBackward>)
# tensor(0.0280, grad_fn=<NegBackward>)
# tensor(0.0279, grad_fn=<NegBackward>)
# tensor(0.0279, grad_fn=<NegBackward>)
# tensor(0.0279, grad_fn=<NegBackward>)
# tensor(0.0278, grad_fn=<NegBackward>)
# tensor(0.0278, grad_fn=<NegBackward>)
# tensor(0.0277, grad_fn=<NegBackward>)
# tensor(0.0277, grad_fn=<NegBackward>)
# tensor(0.0277, grad_fn=<NegBackward>)
# tensor(0.0276, grad_fn=<NegBackward>)
# tensor(0.0276, grad_fn=<NegBackward>)
# tensor(0.0276, grad_fn=<NegBackward>)
# tensor(0.0275, grad_fn=<NegBackward>)
# tensor(0.0275, grad_fn=<NegBackward>)
# tensor(0.0275, grad_fn=<NegBackward>)
# tensor(0.0274, grad_fn=<NegBackward>)
# tensor(0.0274, grad_fn=<NegBackward>)
# tensor(0.0274, grad_fn=<NegBackward>)
# tensor(0.0273, grad_fn=<NegBackward>)
# tensor(0.0273, grad_fn=<NegBackward>)
# tensor(0.0272, grad_fn=<NegBackward>)
# tensor(0.0272, grad_fn=<NegBackward>)
# tensor(0.0272, grad_fn=<NegBackward>)
# tensor(0.0271, grad_fn=<NegBackward>)
# tensor(0.0271, grad_fn=<NegBackward>)
# tensor(0.0271, grad_fn=<NegBackward>)
# tensor(0.0270, grad_fn=<NegBackward>)
# tensor(0.0270, grad_fn=<NegBackward>)
# tensor(0.0270, grad_fn=<NegBackward>)
# tensor(0.0269, grad_fn=<NegBackward>)
# tensor(0.0269, grad_fn=<NegBackward>)
# tensor(0.0269, grad_fn=<NegBackward>)
# tensor(0.0268, grad_fn=<NegBackward>)
# Epoch  700/1000 Cost: 0.026835
# tensor(0.0268, grad_fn=<NegBackward>)
# tensor(0.0268, grad_fn=<NegBackward>)
# tensor(0.0267, grad_fn=<NegBackward>)
# tensor(0.0267, grad_fn=<NegBackward>)
# tensor(0.0267, grad_fn=<NegBackward>)
# tensor(0.0266, grad_fn=<NegBackward>)
# tensor(0.0266, grad_fn=<NegBackward>)
# tensor(0.0266, grad_fn=<NegBackward>)
# tensor(0.0265, grad_fn=<NegBackward>)
# tensor(0.0265, grad_fn=<NegBackward>)
# tensor(0.0265, grad_fn=<NegBackward>)
# tensor(0.0264, grad_fn=<NegBackward>)
# tensor(0.0264, grad_fn=<NegBackward>)
# tensor(0.0264, grad_fn=<NegBackward>)
# tensor(0.0263, grad_fn=<NegBackward>)
# tensor(0.0263, grad_fn=<NegBackward>)
# tensor(0.0263, grad_fn=<NegBackward>)
# tensor(0.0262, grad_fn=<NegBackward>)
# tensor(0.0262, grad_fn=<NegBackward>)
# tensor(0.0262, grad_fn=<NegBackward>)
# tensor(0.0261, grad_fn=<NegBackward>)
# tensor(0.0261, grad_fn=<NegBackward>)
# tensor(0.0261, grad_fn=<NegBackward>)
# tensor(0.0260, grad_fn=<NegBackward>)
# tensor(0.0260, grad_fn=<NegBackward>)
# tensor(0.0260, grad_fn=<NegBackward>)
# tensor(0.0259, grad_fn=<NegBackward>)
# tensor(0.0259, grad_fn=<NegBackward>)
# tensor(0.0259, grad_fn=<NegBackward>)
# tensor(0.0259, grad_fn=<NegBackward>)
# tensor(0.0258, grad_fn=<NegBackward>)
# tensor(0.0258, grad_fn=<NegBackward>)
# tensor(0.0258, grad_fn=<NegBackward>)
# tensor(0.0257, grad_fn=<NegBackward>)
# tensor(0.0257, grad_fn=<NegBackward>)
# tensor(0.0257, grad_fn=<NegBackward>)
# tensor(0.0256, grad_fn=<NegBackward>)
# tensor(0.0256, grad_fn=<NegBackward>)
# tensor(0.0256, grad_fn=<NegBackward>)
# tensor(0.0255, grad_fn=<NegBackward>)
# tensor(0.0255, grad_fn=<NegBackward>)
# tensor(0.0255, grad_fn=<NegBackward>)
# tensor(0.0255, grad_fn=<NegBackward>)
# tensor(0.0254, grad_fn=<NegBackward>)
# tensor(0.0254, grad_fn=<NegBackward>)
# tensor(0.0254, grad_fn=<NegBackward>)
# tensor(0.0253, grad_fn=<NegBackward>)
# tensor(0.0253, grad_fn=<NegBackward>)
# tensor(0.0253, grad_fn=<NegBackward>)
# tensor(0.0252, grad_fn=<NegBackward>)
# tensor(0.0252, grad_fn=<NegBackward>)
# tensor(0.0252, grad_fn=<NegBackward>)
# tensor(0.0252, grad_fn=<NegBackward>)
# tensor(0.0251, grad_fn=<NegBackward>)
# tensor(0.0251, grad_fn=<NegBackward>)
# tensor(0.0251, grad_fn=<NegBackward>)
# tensor(0.0250, grad_fn=<NegBackward>)
# tensor(0.0250, grad_fn=<NegBackward>)
# tensor(0.0250, grad_fn=<NegBackward>)
# tensor(0.0249, grad_fn=<NegBackward>)
# tensor(0.0249, grad_fn=<NegBackward>)
# tensor(0.0249, grad_fn=<NegBackward>)
# tensor(0.0249, grad_fn=<NegBackward>)
# tensor(0.0248, grad_fn=<NegBackward>)
# tensor(0.0248, grad_fn=<NegBackward>)
# tensor(0.0248, grad_fn=<NegBackward>)
# tensor(0.0247, grad_fn=<NegBackward>)
# tensor(0.0247, grad_fn=<NegBackward>)
# tensor(0.0247, grad_fn=<NegBackward>)
# tensor(0.0247, grad_fn=<NegBackward>)
# tensor(0.0246, grad_fn=<NegBackward>)
# tensor(0.0246, grad_fn=<NegBackward>)
# tensor(0.0246, grad_fn=<NegBackward>)
# tensor(0.0245, grad_fn=<NegBackward>)
# tensor(0.0245, grad_fn=<NegBackward>)
# tensor(0.0245, grad_fn=<NegBackward>)
# tensor(0.0245, grad_fn=<NegBackward>)
# tensor(0.0244, grad_fn=<NegBackward>)
# tensor(0.0244, grad_fn=<NegBackward>)
# tensor(0.0244, grad_fn=<NegBackward>)
# tensor(0.0243, grad_fn=<NegBackward>)
# tensor(0.0243, grad_fn=<NegBackward>)
# tensor(0.0243, grad_fn=<NegBackward>)
# tensor(0.0243, grad_fn=<NegBackward>)
# tensor(0.0242, grad_fn=<NegBackward>)
# tensor(0.0242, grad_fn=<NegBackward>)
# tensor(0.0242, grad_fn=<NegBackward>)
# tensor(0.0242, grad_fn=<NegBackward>)
# tensor(0.0241, grad_fn=<NegBackward>)
# tensor(0.0241, grad_fn=<NegBackward>)
# tensor(0.0241, grad_fn=<NegBackward>)
# tensor(0.0240, grad_fn=<NegBackward>)
# tensor(0.0240, grad_fn=<NegBackward>)
# tensor(0.0240, grad_fn=<NegBackward>)
# tensor(0.0240, grad_fn=<NegBackward>)
# tensor(0.0239, grad_fn=<NegBackward>)
# tensor(0.0239, grad_fn=<NegBackward>)
# tensor(0.0239, grad_fn=<NegBackward>)
# tensor(0.0239, grad_fn=<NegBackward>)
# tensor(0.0238, grad_fn=<NegBackward>)
# Epoch  800/1000 Cost: 0.023829
# tensor(0.0238, grad_fn=<NegBackward>)
# tensor(0.0238, grad_fn=<NegBackward>)
# tensor(0.0237, grad_fn=<NegBackward>)
# tensor(0.0237, grad_fn=<NegBackward>)
# tensor(0.0237, grad_fn=<NegBackward>)
# tensor(0.0237, grad_fn=<NegBackward>)
# tensor(0.0236, grad_fn=<NegBackward>)
# tensor(0.0236, grad_fn=<NegBackward>)
# tensor(0.0236, grad_fn=<NegBackward>)
# tensor(0.0236, grad_fn=<NegBackward>)
# tensor(0.0235, grad_fn=<NegBackward>)
# tensor(0.0235, grad_fn=<NegBackward>)
# tensor(0.0235, grad_fn=<NegBackward>)
# tensor(0.0235, grad_fn=<NegBackward>)
# tensor(0.0234, grad_fn=<NegBackward>)
# tensor(0.0234, grad_fn=<NegBackward>)
# tensor(0.0234, grad_fn=<NegBackward>)
# tensor(0.0234, grad_fn=<NegBackward>)
# tensor(0.0233, grad_fn=<NegBackward>)
# tensor(0.0233, grad_fn=<NegBackward>)
# tensor(0.0233, grad_fn=<NegBackward>)
# tensor(0.0233, grad_fn=<NegBackward>)
# tensor(0.0232, grad_fn=<NegBackward>)
# tensor(0.0232, grad_fn=<NegBackward>)
# tensor(0.0232, grad_fn=<NegBackward>)
# tensor(0.0232, grad_fn=<NegBackward>)
# tensor(0.0231, grad_fn=<NegBackward>)
# tensor(0.0231, grad_fn=<NegBackward>)
# tensor(0.0231, grad_fn=<NegBackward>)
# tensor(0.0231, grad_fn=<NegBackward>)
# tensor(0.0230, grad_fn=<NegBackward>)
# tensor(0.0230, grad_fn=<NegBackward>)
# tensor(0.0230, grad_fn=<NegBackward>)
# tensor(0.0230, grad_fn=<NegBackward>)
# tensor(0.0229, grad_fn=<NegBackward>)
# tensor(0.0229, grad_fn=<NegBackward>)
# tensor(0.0229, grad_fn=<NegBackward>)
# tensor(0.0229, grad_fn=<NegBackward>)
# tensor(0.0228, grad_fn=<NegBackward>)
# tensor(0.0228, grad_fn=<NegBackward>)
# tensor(0.0228, grad_fn=<NegBackward>)
# tensor(0.0228, grad_fn=<NegBackward>)
# tensor(0.0227, grad_fn=<NegBackward>)
# tensor(0.0227, grad_fn=<NegBackward>)
# tensor(0.0227, grad_fn=<NegBackward>)
# tensor(0.0227, grad_fn=<NegBackward>)
# tensor(0.0226, grad_fn=<NegBackward>)
# tensor(0.0226, grad_fn=<NegBackward>)
# tensor(0.0226, grad_fn=<NegBackward>)
# tensor(0.0226, grad_fn=<NegBackward>)
# tensor(0.0225, grad_fn=<NegBackward>)
# tensor(0.0225, grad_fn=<NegBackward>)
# tensor(0.0225, grad_fn=<NegBackward>)
# tensor(0.0225, grad_fn=<NegBackward>)
# tensor(0.0224, grad_fn=<NegBackward>)
# tensor(0.0224, grad_fn=<NegBackward>)
# tensor(0.0224, grad_fn=<NegBackward>)
# tensor(0.0224, grad_fn=<NegBackward>)
# tensor(0.0224, grad_fn=<NegBackward>)
# tensor(0.0223, grad_fn=<NegBackward>)
# tensor(0.0223, grad_fn=<NegBackward>)
# tensor(0.0223, grad_fn=<NegBackward>)
# tensor(0.0223, grad_fn=<NegBackward>)
# tensor(0.0222, grad_fn=<NegBackward>)
# tensor(0.0222, grad_fn=<NegBackward>)
# tensor(0.0222, grad_fn=<NegBackward>)
# tensor(0.0222, grad_fn=<NegBackward>)
# tensor(0.0221, grad_fn=<NegBackward>)
# tensor(0.0221, grad_fn=<NegBackward>)
# tensor(0.0221, grad_fn=<NegBackward>)
# tensor(0.0221, grad_fn=<NegBackward>)
# tensor(0.0221, grad_fn=<NegBackward>)
# tensor(0.0220, grad_fn=<NegBackward>)
# tensor(0.0220, grad_fn=<NegBackward>)
# tensor(0.0220, grad_fn=<NegBackward>)
# tensor(0.0220, grad_fn=<NegBackward>)
# tensor(0.0219, grad_fn=<NegBackward>)
# tensor(0.0219, grad_fn=<NegBackward>)
# tensor(0.0219, grad_fn=<NegBackward>)
# tensor(0.0219, grad_fn=<NegBackward>)
# tensor(0.0218, grad_fn=<NegBackward>)
# tensor(0.0218, grad_fn=<NegBackward>)
# tensor(0.0218, grad_fn=<NegBackward>)
# tensor(0.0218, grad_fn=<NegBackward>)
# tensor(0.0218, grad_fn=<NegBackward>)
# tensor(0.0217, grad_fn=<NegBackward>)
# tensor(0.0217, grad_fn=<NegBackward>)
# tensor(0.0217, grad_fn=<NegBackward>)
# tensor(0.0217, grad_fn=<NegBackward>)
# tensor(0.0217, grad_fn=<NegBackward>)
# tensor(0.0216, grad_fn=<NegBackward>)
# tensor(0.0216, grad_fn=<NegBackward>)
# tensor(0.0216, grad_fn=<NegBackward>)
# tensor(0.0216, grad_fn=<NegBackward>)
# tensor(0.0215, grad_fn=<NegBackward>)
# tensor(0.0215, grad_fn=<NegBackward>)
# tensor(0.0215, grad_fn=<NegBackward>)
# tensor(0.0215, grad_fn=<NegBackward>)
# tensor(0.0215, grad_fn=<NegBackward>)
# tensor(0.0214, grad_fn=<NegBackward>)
# Epoch  900/1000 Cost: 0.021433
# tensor(0.0214, grad_fn=<NegBackward>)
# tensor(0.0214, grad_fn=<NegBackward>)
# tensor(0.0214, grad_fn=<NegBackward>)
# tensor(0.0213, grad_fn=<NegBackward>)
# tensor(0.0213, grad_fn=<NegBackward>)
# tensor(0.0213, grad_fn=<NegBackward>)
# tensor(0.0213, grad_fn=<NegBackward>)
# tensor(0.0213, grad_fn=<NegBackward>)
# tensor(0.0212, grad_fn=<NegBackward>)
# tensor(0.0212, grad_fn=<NegBackward>)
# tensor(0.0212, grad_fn=<NegBackward>)
# tensor(0.0212, grad_fn=<NegBackward>)
# tensor(0.0212, grad_fn=<NegBackward>)
# tensor(0.0211, grad_fn=<NegBackward>)
# tensor(0.0211, grad_fn=<NegBackward>)
# tensor(0.0211, grad_fn=<NegBackward>)
# tensor(0.0211, grad_fn=<NegBackward>)
# tensor(0.0211, grad_fn=<NegBackward>)
# tensor(0.0210, grad_fn=<NegBackward>)
# tensor(0.0210, grad_fn=<NegBackward>)
# tensor(0.0210, grad_fn=<NegBackward>)
# tensor(0.0210, grad_fn=<NegBackward>)
# tensor(0.0209, grad_fn=<NegBackward>)
# tensor(0.0209, grad_fn=<NegBackward>)
# tensor(0.0209, grad_fn=<NegBackward>)
# tensor(0.0209, grad_fn=<NegBackward>)
# tensor(0.0209, grad_fn=<NegBackward>)
# tensor(0.0208, grad_fn=<NegBackward>)
# tensor(0.0208, grad_fn=<NegBackward>)
# tensor(0.0208, grad_fn=<NegBackward>)
# tensor(0.0208, grad_fn=<NegBackward>)
# tensor(0.0208, grad_fn=<NegBackward>)
# tensor(0.0207, grad_fn=<NegBackward>)
# tensor(0.0207, grad_fn=<NegBackward>)
# tensor(0.0207, grad_fn=<NegBackward>)
# tensor(0.0207, grad_fn=<NegBackward>)
# tensor(0.0207, grad_fn=<NegBackward>)
# tensor(0.0206, grad_fn=<NegBackward>)
# tensor(0.0206, grad_fn=<NegBackward>)
# tensor(0.0206, grad_fn=<NegBackward>)
# tensor(0.0206, grad_fn=<NegBackward>)
# tensor(0.0206, grad_fn=<NegBackward>)
# tensor(0.0205, grad_fn=<NegBackward>)
# tensor(0.0205, grad_fn=<NegBackward>)
# tensor(0.0205, grad_fn=<NegBackward>)
# tensor(0.0205, grad_fn=<NegBackward>)
# tensor(0.0205, grad_fn=<NegBackward>)
# tensor(0.0204, grad_fn=<NegBackward>)
# tensor(0.0204, grad_fn=<NegBackward>)
# tensor(0.0204, grad_fn=<NegBackward>)
# tensor(0.0204, grad_fn=<NegBackward>)
# tensor(0.0204, grad_fn=<NegBackward>)
# tensor(0.0203, grad_fn=<NegBackward>)
# tensor(0.0203, grad_fn=<NegBackward>)
# tensor(0.0203, grad_fn=<NegBackward>)
# tensor(0.0203, grad_fn=<NegBackward>)
# tensor(0.0203, grad_fn=<NegBackward>)
# tensor(0.0203, grad_fn=<NegBackward>)
# tensor(0.0202, grad_fn=<NegBackward>)
# tensor(0.0202, grad_fn=<NegBackward>)
# tensor(0.0202, grad_fn=<NegBackward>)
# tensor(0.0202, grad_fn=<NegBackward>)
# tensor(0.0202, grad_fn=<NegBackward>)
# tensor(0.0201, grad_fn=<NegBackward>)
# tensor(0.0201, grad_fn=<NegBackward>)
# tensor(0.0201, grad_fn=<NegBackward>)
# tensor(0.0201, grad_fn=<NegBackward>)
# tensor(0.0201, grad_fn=<NegBackward>)
# tensor(0.0200, grad_fn=<NegBackward>)
# tensor(0.0200, grad_fn=<NegBackward>)
# tensor(0.0200, grad_fn=<NegBackward>)
# tensor(0.0200, grad_fn=<NegBackward>)
# tensor(0.0200, grad_fn=<NegBackward>)
# tensor(0.0200, grad_fn=<NegBackward>)
# tensor(0.0199, grad_fn=<NegBackward>)
# tensor(0.0199, grad_fn=<NegBackward>)
# tensor(0.0199, grad_fn=<NegBackward>)
# tensor(0.0199, grad_fn=<NegBackward>)
# tensor(0.0199, grad_fn=<NegBackward>)
# tensor(0.0198, grad_fn=<NegBackward>)
# tensor(0.0198, grad_fn=<NegBackward>)
# tensor(0.0198, grad_fn=<NegBackward>)
# tensor(0.0198, grad_fn=<NegBackward>)
# tensor(0.0198, grad_fn=<NegBackward>)
# tensor(0.0197, grad_fn=<NegBackward>)
# tensor(0.0197, grad_fn=<NegBackward>)
# tensor(0.0197, grad_fn=<NegBackward>)
# tensor(0.0197, grad_fn=<NegBackward>)
# tensor(0.0197, grad_fn=<NegBackward>)
# tensor(0.0197, grad_fn=<NegBackward>)
# tensor(0.0196, grad_fn=<NegBackward>)
# tensor(0.0196, grad_fn=<NegBackward>)
# tensor(0.0196, grad_fn=<NegBackward>)
# tensor(0.0196, grad_fn=<NegBackward>)
# tensor(0.0196, grad_fn=<NegBackward>)
# tensor(0.0195, grad_fn=<NegBackward>)
# tensor(0.0195, grad_fn=<NegBackward>)
# tensor(0.0195, grad_fn=<NegBackward>)
# tensor(0.0195, grad_fn=<NegBackward>)
# tensor(0.0195, grad_fn=<NegBackward>)
# Epoch 1000/1000 Cost: 0.019477

# %%
print(W,b)
hypothesis = torch.sigmoid(x_train.matmul(W) + b)
prediction = hypothesis >= torch.FloatTensor([0.5])
print(prediction)
# Out:
# tensor([[3.2715],
#         [1.5279]], requires_grad=True) tensor([-14.5674], requires_grad=True)
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
